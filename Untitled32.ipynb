# %%
/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce

/usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning:

invalid value encountered in reduce


---------------------------------------------------------------------------
KeyboardInterrupt                         Traceback (most recent call last)
Cell In[50], line 773
    771 try:
    772     print("Starting multi-pass backtest...")
--> 773     weights = qnbt.backtest(
    774         competition_type="stocks_s&p500",
    775         load_data=load_data,
    776         lookback_period=LOOKBACK_PERIOD,
    777         start_date=BACKTEST_START_DATE,
    778         strategy=strategy
    779     )
    780     print("Multi-pass backtest completed.")
    782     print("Checking final weights for QNT constraints...")

File ~/book/qnt/backtester.py:469, in backtest(competition_type, strategy, load_data, lookback_period, test_period, start_date, end_date, window, step, analyze, build_plots, collect_all_states, check_correlation)
    466 # ---
    468 log_info("---")
--> 469 result, state = run_iterations(time_series, data, window, start_date, lookback_period, strategy_wrap, step,
    470                                collect_all_states)
    471 if result is None:
    472     return

File ~/book/qnt/backtester.py:518, in run_iterations(time_series, data, window, start_date, lookback_period, strategy, step, collect_all_states)
    516 for i, t in enumerate(output_time_coord):
    517     tail = copy_window(data, t, lookback_period)
--> 518     result = strategy(tail, copy.deepcopy(state))
    519     output, state = unpack_result(result)
    521     if not isinstance(output, xr.DataArray):

File ~/book/qnt/backtester.py:401, in backtest.<locals>.<lambda>(d, s)
    398     load_data = lambda tail: qndata.load_data_by_type(competition_type, tail=tail)
    400 args_count = len(inspect.getfullargspec(strategy).args)
--> 401 strategy_wrap = (lambda d, s: strategy(d)) if args_count < 2 else strategy
    403 # ---
    404 log_info("Run last pass...")

Cell In[50], line 734, in strategy(data)
    731     transform_func = vedic_poly_transform
    733 # Apply the full Vedic transform (synergy of 16 main & 13 sub sutras).
--> 734 full_transformed = FullVedicTransform.apply(projected, base=13)
    736 # Apply Sulba Sutras geometric transformation for additional nonlinearity.
    737 sulba_signal = SulbaSutras.sulba_transform(full_transformed, factor=0.75)

Cell In[50], line 618, in FullVedicTransform.apply(signal, base)
    616         result = signal
    617     main_outputs.append(result)
--> 618 main_combined = sum(main_outputs) / len(main_outputs)
    620 sub_funcs = [
    621     SubSutras13.anurupyena,
    622     SubSutras13.sisyate_sesasamjnah,
   (...)
    633     SubSutras13.gunitasamuccayah_samuccayagunitah
    634 ]
    635 sub_outputs = []

File /usr/local/lib/python3.10/site-packages/xarray/core/_typed_ops.py:246, in DataArrayOpsMixin.__add__(self, other)
    245 def __add__(self, other: DaCompatible) -> Self:
--> 246     return self._binary_op(other, operator.add)

File /usr/local/lib/python3.10/site-packages/xarray/core/dataarray.py:4726, in DataArray._binary_op(self, other, f, reflexive)
   4722 other_variable_or_arraylike: DaCompatible = getattr(other, "variable", other)
   4723 other_coords = getattr(other, "coords", None)
   4725 variable = (
-> 4726     f(self.variable, other_variable_or_arraylike)
   4727     if not reflexive
   4728     else f(other_variable_or_arraylike, self.variable)
   4729 )
   4730 coords, indexes = self.coords._merge_raw(other_coords, reflexive)
   4731 name = self._result_name(other)

File /usr/local/lib/python3.10/site-packages/xarray/core/_typed_ops.py:464, in VariableOpsMixin.__add__(self, other)
    463 def __add__(self, other: VarCompatible) -> Self | T_DataArray:
--> 464     return self._binary_op(other, operator.add)

File /usr/local/lib/python3.10/site-packages/xarray/core/variable.py:2317, in Variable._binary_op(self, other, f, reflexive)
   2314 attrs = self._attrs if keep_attrs else None
   2315 with np.errstate(all="ignore"):
   2316     new_data = (
-> 2317         f(self_data, other_data) if not reflexive else f(other_data, self_data)
   2318     )
   2319 result = Variable(dims, new_data, attrs=attrs)
   2320 return result

KeyboardInterrupt:
# Out:
#   File "<ipython-input-1-5bb91e3521d9>", line 1
#     usr/local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88:(RuntimeWarning:)
#                          ^
# SyntaxError: invalid syntax
