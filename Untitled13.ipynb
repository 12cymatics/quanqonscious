# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Sample data
time = np.linspace(0, 12, 100)
qubits = np.linspace(1, 128, 100)
thresholds = np.linspace(0.5, 1.5, 100)

# Plotting
ax.plot3D(time, qubits, thresholds, c='b', label='Vedic-Quantum')
ax.plot3D(time, qubits, thresholds + 0.2, c='r', label='Classical')

ax.set_xlabel('Time (Months)')
ax.set_ylabel('Number of Qubits')
ax.set_zlabel('Threshold (nats)')

plt.show()
